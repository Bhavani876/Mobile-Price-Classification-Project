# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
train=pd.read_csv("train.csv")
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
train.shape
# Out:
# (2000, 21)

# %%
train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
test=pd.read_csv("test.csv")
test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
test.shape
# Out:
# (1000, 21)

# %%
test.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %% [markdown]
# # Data Exploration

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
train.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.figure(figsize=(25,10))
sb.heatmap(train.corr(),annot=True,linecolor='k',linewidths=.5,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# conclusion:- ram have to be excluded in our analysis beacauses they corrleate with the 'price_range' variable.

# %% [markdown]
# # Finding Null Vlaues

# %%
train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# # Visualizations

# %% [markdown]
# # mobile_wt and price_range

# %%
sb.barplot(data=train,x='price_range',y='mobile_wt')
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='mobile_wt'>

# %% [markdown]
# # int_memory and price_range

# %%
sb.pointplot(data=train,x='price_range',y='int_memory');

# %% [markdown]
# # ram and price_range

# %%
sb.jointplot(data=train,x='ram',y='price_range',kind='kde');

# %% [markdown]
# # Battery power and price_range

# %%
sb.boxplot(data=train,x='price_range',y='battery_power');

# %% [markdown]
# # Model Buliding

# %%
x=train.drop(columns='price_range',axis=1)
y=train['price_range']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_train=scale.fit_transform(x_train)
x_test=scale.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
model=LR.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.9766666666666667

# %%
from sklearn.svm import SVC
sm=SVC()
model=sm.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.9866666666666667

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
model=knn.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.7073333333333334

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
model=RF.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 1.0

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([0, 1, 0, 2, 1, 1, 1, 0, 3, 1, 0, 1, 1, 3, 2, 2, 3, 3, 0, 0, 0, 1,
#        0, 1, 0, 1, 3, 2, 1, 0, 2, 0, 2, 0, 2, 3, 2, 0, 3, 0, 1, 2, 3, 0,
#        2, 0, 1, 2, 3, 0, 1, 0, 1, 0, 1, 2, 3, 2, 0, 1, 0, 2, 2, 2, 0, 1,
#        3, 3, 2, 3, 1, 3, 0, 2, 2, 1, 0, 3, 2, 1, 3, 0, 1, 1, 0, 3, 1, 3,
#        3, 0, 3, 3, 3, 2, 3, 1, 1, 3, 2, 1, 0, 1, 1, 0, 0, 2, 2, 0, 2, 1,
#        0, 1, 2, 2, 1, 0, 3, 2, 0, 2, 1, 1, 3, 1, 3, 1, 0, 2, 1, 2, 2, 0,
#        1, 2, 1, 3, 1, 1, 0, 2, 3, 1, 3, 2, 1, 0, 2, 0, 2, 2, 3, 0, 1, 0,
#        3, 3, 0, 1, 1, 1, 1, 2, 2, 1, 2, 0, 1, 3, 3, 2, 2, 0, 1, 1, 2, 0,
#        0, 2, 1, 0, 0, 0, 2, 0, 1, 3, 2, 2, 0, 0, 1, 1, 1, 3, 3, 2, 3, 0,
#        1, 0, 1, 1, 1, 3, 2, 2, 0, 2, 0, 0, 0, 2, 2, 1, 1, 2, 0, 2, 0, 1,
#        2, 1, 2, 0, 0, 2, 2, 3, 0, 1, 1, 0, 1, 3, 2, 0, 0, 3, 2, 0, 1, 2,
#        1, 3, 0, 2, 1, 1, 2, 1, 1, 3, 0, 3, 3, 2, 1, 2, 1, 2, 3, 1, 3, 2,
#        1, 2, 2, 0, 1, 3, 1, 1, 1, 2, 0, 1, 1, 3, 2, 1, 2, 1, 0, 3, 1, 3,
# ...

# %%
from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(y_predict,y_test)
cm1
# Out:
# array([[94, 34,  7,  2],
#        [30, 52, 50, 16],
#        [ 7, 26, 46, 45],
#        [ 1,  6, 17, 67]], dtype=int64)

# %%
from sklearn.metrics import classification_report,accuracy_score,precision_score,recall_score,f1_score
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.69      0.70       137
#            1       0.44      0.35      0.39       148
#            2       0.38      0.37      0.38       124
#            3       0.52      0.74      0.61        91
#
#     accuracy                           0.52       500
#    macro avg       0.51      0.54      0.52       500
# weighted avg       0.51      0.52      0.51       500

# %% [markdown]
# Conclusion:-Comparing all algorithms. Random Forests is getting highest accuracy .
